# %%
#usando somente o exemplo de 10*5 para não usar inputs e testar o Databricks Notebook
print ("\nCalculadora Python")

def addNum(x, y):
    return x + y

def addNum(x, y):
    return x + y

def multNum(x, y):
    return x * y

def divNum(x, y):
    return x / y

print("\nSelecione o número da operação desejada: \n")
print("1 - Soma")
print("2 - Subtração")
print("3 - Multiplicação")
print("4 - Divisão")

print("10 * 5 = ", multNum(10,5))
# Out:
# Calculadora Python
#
# Selecione o número da operação desejada:
#
# 1 - Soma
# 2 - Subtração
# 3 - Multiplicação
# 4 - Divisão
# 10 * 5 =  50

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
